# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Time searise analysis

# %%
df = pd.DataFrame(np.random.randn(100), index=pd.date_range('2017-01-01', periods=100), columns=['value'])

# %%
df.head()
# Out:
#                value
# 2017-01-01  0.095510
# 2017-01-02 -0.320472
# 2017-01-03  1.720270
# 2017-01-04 -0.564944
# 2017-01-05  1.579726

# %%
df.tail()
# Out:
#                value
# 2017-04-06  2.609575
# 2017-04-07 -0.090959
# 2017-04-08  0.939491
# 2017-04-09 -0.520976
# 2017-04-10 -0.553693

# %%
# line chart
df.plot()
# Out:
# <AxesSubplot:>

# %%
# bar plot
df.head(10).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df.plot.bar()
# Out:
# <AxesSubplot:>

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.plot()
# Out:
# <AxesSubplot:>

# %%
iris.plot(figsize=(15, 6))
# Out:
# <AxesSubplot:>

# %%
iris.plot(kind='bar', figsize=(15, 6))
# Out:
# <AxesSubplot:>

# %%
# df2 = pd.read_csv("googleplaystore.csv")
# df2 = pd.read_csv("googleplaystore.csv")df2 = pd.read_csv("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/car_crashes.csv")

# %%
iris.iloc[0]
# Out:
# sepal_length       5.1
# sepal_width        3.5
# petal_length       1.4
# petal_width        0.2
# species         setosa
# Name: 0, dtype: object

# %%
iris.drop('species', axis=1).iloc[0].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.drop('species', axis=1).iloc[0].plot.bar()
# Out:
# <AxesSubplot:>

# %%
iris.drop('species', axis=1).iloc[0].plot.barh()
# Out:
# <AxesSubplot:>

# %%
iris.drop('species', axis=1).iloc[0].plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
iris['sepal_length'].head(50).plot(kind='bar', figsize=(10, 5))
# Out:
# <AxesSubplot:>

# %%
iris['sepal_length'].head(50).plot(kind='hist', figsize=(10, 5))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot(kind='hist', bins=80, figsize=(10, 5))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot(kind='hist', bins=80, figsize=(10, 5), orientation='horizontal')
# Out:
# <AxesSubplot:xlabel='Frequency'>

# %%
iris.hist(color='blue', alpha=0.1, figsize=(10, 10))
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)
